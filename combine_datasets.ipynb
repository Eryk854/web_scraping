# %%
import pandas as pd

# %%
df_otodom = pd.read_csv("otodom/otodom_before_merge.csv", sep="\t")
df_nieruchomosci = pd.read_csv("nieruchomosci/nieruchomosci_online_before_merge.csv", sep="\t")

# %%
print(df_otodom.shape)
df_nieruchomosci.shape
# Out:
# (34669, 24)
# (27798, 24)

# %%
df = pd.concat([df_otodom, df_nieruchomosci])

# %%
df
# Out:
#        Miasto                                                URL       Cena  \
# 0      gdansk  https://www.otodom.pl/pl/oferta/mieszkanie-1-p...   375000.0
# 1      gdansk  https://www.otodom.pl/pl/oferta/kilometr-do-mo...   519000.0
# 2      gdansk  https://www.otodom.pl/pl/oferta/funkcjonalna-k...   389000.0
# 3      gdansk  https://www.otodom.pl/pl/oferta/7-minut-rowere...   395000.0
# 4      gdansk  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...   390500.0
# ...       ...                                                ...        ...
# 27793  krakow  https://krakow.nieruchomosci-online.pl/mieszka...   658944.0
# 27794  krakow  https://krakow.nieruchomosci-online.pl/mieszka...  1077640.0
# 27795  krakow  https://krakow.nieruchomosci-online.pl/mieszka...   780000.0
# 27796  krakow  https://krakow.nieruchomosci-online.pl/mieszka...   515000.0
# 27797  krakow  https://krakow.nieruchomosci-online.pl/mieszka...  1020240.0
#
# ...

# %%
df.to_csv("merge_dataset.csv", index=False, sep="\t")
